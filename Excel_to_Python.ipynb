# %%
from functions import *
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
### Note: There is a minor error in functions.py. (about the number of article limit for Bing) I'll fix it ASAP and remove this note

# %%
np.arange(0, 1, step=0.2)
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8])

# %%
e = pd.read_excel("numbers_and_dates_new.xlsx")
e
# Out:
#                                                 Query  ...                                               days
# 0             Vessel caught misreporting catch amount  ...  [14, 234, 30, 331, 88, 282, 69, 886, 984, 1047...
# 1             Vessel caught misreporting catch amount  ...  [13, 12, 12, 13, 8, 12, 8, 12, 13, 8, 12, 12, ...
# 2               Vessel caught falsifying fishing logs  ...  [93, 261, 120, 268, 7, 295, 192, 207, 294, 309...
# 3               Vessel caught falsifying fishing logs  ...  [18, 12, 2, 24, 60, 3, 30, 15, 30, 30, 15, 15,...
# 4          Vessel caught with incorrect catch reports  ...  [3, 90, 256, 171, 227, 241, 331, 351, 288, 288...
# 5          Vessel caught with incorrect catch reports  ...         [2, 2, 12, 3, 5, 8, 3, 12, 12, 12, 12, 12]
# 6   Vessel caught underreporting catch in North At...  ...  [394, 634, 3076, 408, 3075, 3791, 463, 2481, 1...
# 7   Vessel caught underreporting catch in North At...  ...            [1, 30, 3, 12, 9, 8, 22, 15, 3, 12, 12]
# 8            Vessel caught misreporting haddock catch  ...                                        [1351, 632]
# 9            Vessel caught misreporting haddock catch  ...  [30, 3, 23, 120, 60,1460,210,15,5110,3,270,365...
# 10    Vessel caught with inaccurate fish size records  ...  [3, 303, 228, 504, 984, 413, 441, 4412, 1138, ...
# 11    Vessel caught with inaccurate fish size records  ...  [2190, 7304,3,14,365,1095,3,2, 30,120,3,1095,7...
# 12  Vessel caught underreporting catch near protec...  ...  [112, 80, 30, 69, 3642, 598, 3417, 1032, 3951,...
# 13  Vessel caught underreporting catch near protec...  ...  [4, 30, 19, 15, 30, 60, 23, 17, 12, 15, 25, 27...
# 14   Vessel caught misreporting tuna catch quantities  ...  [984, 1996, 1103, 869, 4972, 2698, 1336, 4480,...
# 15   Vessel caught misreporting tuna catch quantities  ...  [60, 365, 6, 4, 2190, 3, 730, 3, 730,730,7,6,7...
# 16         Vessel caught with unrecorded fish species  ...  [7, 333, 228, 72, 380, 366, 203, 1485, 253, 10...
# 17         Vessel caught with unrecorded fish species  ...  [730, 730, 730, 3, 3, 12, 12, 27, 30, 15, 8, 6...
# 18               Vessel caught bypassing quota system  ...                        [14, 340, 2965, 5122, 1676]
# 19               Vessel caught bypassing quota system  ...  [730, 2, 730, 8, 6, 15, 12, 9, 7, 1, 15, 23, 1...
# 20            Vessel caught misreporting catch amount  ...                                                 []
# 21              Vessel caught falsifying fishing logs  ...                                                 []
# 22         Vessel caught with incorrect catch reports  ...                       [360, 330, 90, 730, 365, 30]
# 23  Vessel caught underreporting catch in North At...  ...                                                 []
# 24           Vessel caught misreporting haddock catch  ...                                                 []
# 25    Vessel caught with inaccurate fish size records  ...                                                 []
# 26  Vessel caught underreporting catch near protec...  ...                                                 []
# 27   Vessel caught misreporting tuna catch quantities  ...                                                 []
# 28         Vessel caught with unrecorded fish species  ...                                                 []
# 29               Vessel caught bypassing quota system  ...                                                 []
#
# [30 rows x 5 columns]

# %%
#queries= ['Vessel caught misreporting catch amount', 'Vessel caught falsifying fishing logs', 'Vessel caught with incorrect catch reports',
    #'Vessel caught underreporting catch in North Atlantic', 'Vessel caught misreporting haddock catch', 
     #'Vessel caught with inaccurate fish size records', 'Vessel caught underreporting catch near protected area',
    #'Vessel caught misreporting tuna catch quantities', 'Vessel caught with unrecorded fish species', 
    #'Vessel caught bypassing quota system']

# %%
article_counts = e.groupby(['Query', 'Engine', 'results']).size().reset_index(name='Article Count')
ac = article_counts.drop(['Article Count'], axis=1)
ac
# Out:
#                                                 Query  Engine  results
# 0                Vessel caught bypassing quota system    Bing       14
# 1                Vessel caught bypassing quota system  Google        5
# 2                Vessel caught bypassing quota system   Yahoo        0
# 3               Vessel caught falsifying fishing logs    Bing       14
# 4               Vessel caught falsifying fishing logs  Google       20
# 5               Vessel caught falsifying fishing logs   Yahoo        0
# 6             Vessel caught misreporting catch amount    Bing       14
# 7             Vessel caught misreporting catch amount  Google       20
# 8             Vessel caught misreporting catch amount   Yahoo        0
# 9            Vessel caught misreporting haddock catch    Bing       14
# 10           Vessel caught misreporting haddock catch  Google        2
# 11           Vessel caught misreporting haddock catch   Yahoo        0
# 12   Vessel caught misreporting tuna catch quantities    Bing       14
# 13   Vessel caught misreporting tuna catch quantities  Google       13
# 14   Vessel caught misreporting tuna catch quantities   Yahoo        0
# 15  Vessel caught underreporting catch in North At...    Bing       11
# 16  Vessel caught underreporting catch in North At...  Google       14
# 17  Vessel caught underreporting catch in North At...   Yahoo        0
# 18  Vessel caught underreporting catch near protec...    Bing       14
# 19  Vessel caught underreporting catch near protec...  Google       20
# 20  Vessel caught underreporting catch near protec...   Yahoo        0
# 21    Vessel caught with inaccurate fish size records    Bing       14
# 22    Vessel caught with inaccurate fish size records  Google       20
# 23    Vessel caught with inaccurate fish size records   Yahoo        0
# 24         Vessel caught with incorrect catch reports    Bing       12
# 25         Vessel caught with incorrect catch reports  Google       20
# 26         Vessel caught with incorrect catch reports   Yahoo        6
# 27         Vessel caught with unrecorded fish species    Bing       14
# 28         Vessel caught with unrecorded fish species  Google       20
# 29         Vessel caught with unrecorded fish species   Yahoo        0

# %%
# just in case to know what happen
Q_1 = ac['Query'].iloc[0]
Q_2 = ac['Query'].iloc[3]
Q_3 = ac['Query'].iloc[6]
Q_4 = ac['Query'].iloc[9]
Q_5 = ac['Query'].iloc[12]
Q_6 = ac['Query'].iloc[15]
Q_7 = ac['Query'].iloc[18]
Q_8 = ac['Query'].iloc[21]
Q_9 = ac['Query'].iloc[24]
Q_10 = ac['Query'].iloc[27]

# create the list of queries
queries_list = [ac['Query'].iloc[i] for i in range(0, 28, 3)]
# checking
# print(queries_list)

# %% [markdown]
# ### 'Number of Articles per Query and Engine'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Grouping and resetting index
article_counts = e.groupby(['Query', 'Engine', 'results']).size().reset_index(name='Article Count')

# Dropping the 'Article Count' column
ac = article_counts.drop(['Article Count'], axis=1)

# Extracting every third query from the 'Query' column
queries_list = [ ac['Query'].iloc[i] for i in range(0, len(ac['Query']), 3)]

queries_labels = [f'Q_{i}' for i in range(1, 11)]

# Filtering the DataFrame to only include the queries in queries_list
filtered_ac = ac[ac['Query'].isin(queries_list)]

#color = ['lightblue', 'lightpurple', 'lightgreen']
# Plotting
plt.figure(figsize=(9, 6))
sns.barplot(x='Query', y='results', hue='Engine', data=filtered_ac )
plt.title('Number of Articles per Query and Engine', fontsize=14)

# Set xticks with query names
plt.xticks(ticks=range(len(queries_labels)), labels=queries_labels, rotation=0, ha='right')
plt.xlabel('Query', fontsize=14)
plt.ylabel('Number of Articles', fontsize=14)
plt.legend(title='Engine', loc='upper left')
plt.tight_layout()
plt.grid(axis = 'y', linestyle='--')
# Show the plot
plt.show()

# %%
article_counts1 = e.groupby(['Query', 'Engine', 'days']).size().reset_index(name='Article Count')
ac1 = article_counts1.drop(['Article Count'], axis=1)
ac1
# Out:
#                                                 Query  ...                                               days
# 0                Vessel caught bypassing quota system  ...  [60, 2, 60, 8, 6, 15, 12, 9, 7, 1, 15, 23, 12, 3]
# 1                Vessel caught bypassing quota system  ...                        [14, 340, 2965, 5122, 1676]
# 2                Vessel caught bypassing quota system  ...                                                 []
# 3               Vessel caught falsifying fishing logs  ...  [18, 12, 2, 24, 1, 3, 1, 15, 1, 1, 15, 15, 15, 5]
# 4               Vessel caught falsifying fishing logs  ...  [93, 261, 120, 268, 7, 295, 192, 207, 294, 309...
# 5               Vessel caught falsifying fishing logs  ...                                                 []
# 6             Vessel caught misreporting catch amount  ...  [13, 12, 12, 13, 8, 12, 8, 12, 13, 8, 12, 12, ...
# 7             Vessel caught misreporting catch amount  ...  [14, 234, 30, 331, 88, 282, 69, 886, 984, 1047...
# 8             Vessel caught misreporting catch amount  ...                                                 []
# 9            Vessel caught misreporting haddock catch  ...  [1, 3, 23, 1, 1, 120, 1, 15, 420, 3, 1, 210, 3...
# 10           Vessel caught misreporting haddock catch  ...                                        [1351, 632]
# 11           Vessel caught misreporting haddock catch  ...                                                 []
# 12   Vessel caught misreporting tuna catch quantities  ...  [1, 30, 6, 4, 180, 3, 60, 3, 60, 60, 7, 6, 60, 1]
# 13   Vessel caught misreporting tuna catch quantities  ...  [984, 1996, 1103, 869, 4972, 2698, 1336, 4480,...
# 14   Vessel caught misreporting tuna catch quantities  ...                                                 []
# 15  Vessel caught underreporting catch in North At...  ...             [1, 1, 3, 12, 9, 8, 22, 15, 3, 12, 12]
# 16  Vessel caught underreporting catch in North At...  ...  [394, 634, 3076, 408, 3075, 3791, 463, 2481, 1...
# 17  Vessel caught underreporting catch in North At...  ...                                                 []
# 18  Vessel caught underreporting catch near protec...  ...  [4, 1, 19, 15, 1, 1, 23, 17, 12, 15, 25, 1, 16...
# 19  Vessel caught underreporting catch near protec...  ...  [112, 80, 30, 69, 3642, 598, 3417, 1032, 3951,...
# 20  Vessel caught underreporting catch near protec...  ...                                                 []
# 21    Vessel caught with inaccurate fish size records  ...  [180, 60, 4, 3, 14, 30, 90, 3, 60, 1, 1, 3, 90...
# 22    Vessel caught with inaccurate fish size records  ...  [3, 303, 228, 504, 984, 413, 441, 4412, 1138, ...
# 23    Vessel caught with inaccurate fish size records  ...                                                 []
# 24         Vessel caught with incorrect catch reports  ...         [2, 2, 12, 3, 5, 8, 3, 12, 12, 12, 12, 12]
# 25         Vessel caught with incorrect catch reports  ...  [3, 90, 256, 171, 227, 241, 331, 351, 288, 288...
# 26         Vessel caught with incorrect catch reports  ...                       [360, 330, 90, 730, 365, 30]
# 27         Vessel caught with unrecorded fish species  ...  [60, 60, 60, 3, 3, 12, 12, 27, 1, 15, 8, 6, 8,...
# 28         Vessel caught with unrecorded fish species  ...  [7, 333, 228, 72, 380, 366, 203, 1485, 253, 10...
# 29         Vessel caught with unrecorded fish species  ...                                                 []
#
# [30 rows x 3 columns]

# %%
type(ac1["days"].iloc[0])
type(eval(ac1["days"].iloc[0]))
len(eval(ac1["days"].iloc[0]))
# Out:
# 14

# %% [markdown]
# ### Calculate the Variances:

# %%
# Sample DataFrame creation (replace this with your actual DataFrame)
# ac1 = pd.DataFrame({
#     "days": ['[60, 2, 60, 8, 6, 15, 12, 9, 7, 1, 15, 23, 12, 3]', '[10, 20, 30, 40, 50]']
# })

# Initialize an empty list to store variances
variances = []

# Loop through each row in the DataFrame
for i in range(len(ac1)):
    # Extract the list from the string
    days_list = eval(ac1["days"].iloc[i])
    if days_list == []:
        variance = 0
    else:
    # Calculate the standard deviation of the list
        variance = np.std(days_list)
    # Append the variance to the list
    variances.append(variance)

# Assign the list of variances to the "Variance" column in the DataFrame
ac1["Variance"] = variances

# Print the DataFrame to verify
print(ac1)
# Out:
#                                                 Query  ...     Variance
# 0                Vessel caught bypassing quota system  ...    18.580355
# 1                Vessel caught bypassing quota system  ...  1869.767002
# 2                Vessel caught bypassing quota system  ...     0.000000
# 3               Vessel caught falsifying fishing logs  ...     7.633171
# 4               Vessel caught falsifying fishing logs  ...   318.686758
# 5               Vessel caught falsifying fishing logs  ...     0.000000
# 6             Vessel caught misreporting catch amount  ...     1.840586
# 7             Vessel caught misreporting catch amount  ...   641.870335
# 8             Vessel caught misreporting catch amount  ...     0.000000
# 9            Vessel caught misreporting haddock catch  ...   115.687651
# 10           Vessel caught misreporting haddock catch  ...   359.500000
# 11           Vessel caught misreporting haddock catch  ...     0.000000
# 12   Vessel caught misreporting tuna catch quantities  ...    47.306912
# 13   Vessel caught misreporting tuna catch quantities  ...  1336.596278
# 14   Vessel caught misreporting tuna catch quantities  ...     0.000000
# 15  Vessel caught underreporting catch in North At...  ...     6.273386
# 16  Vessel caught underreporting catch in North At...  ...  1379.620119
# 17  Vessel caught underreporting catch in North At...  ...     0.000000
# 18  Vessel caught underreporting catch near protec...  ...     8.209005
# 19  Vessel caught underreporting catch near protec...  ...  1217.536862
# 20  Vessel caught underreporting catch near protec...  ...     0.000000
# 21    Vessel caught with inaccurate fish size records  ...    49.937359
# 22    Vessel caught with inaccurate fish size records  ...  1266.872380
# 23    Vessel caught with inaccurate fish size records  ...     0.000000
# 24         Vessel caught with incorrect catch reports  ...     4.348531
# 25         Vessel caught with incorrect catch reports  ...   526.767748
# 26         Vessel caught with incorrect catch reports  ...   226.858069
# 27         Vessel caught with unrecorded fish species  ...    21.514708
# 28         Vessel caught with unrecorded fish species  ...   594.907428
# 29         Vessel caught with unrecorded fish species  ...     0.000000
#
# [30 rows x 4 columns]

# %%
# Define the value to remove and the column name
value_to_remove = 'Yahoo'
col_name = ac1['Engine']

# Drop rows where the specified column has the specific value
ac2 = ac1[ac1['Engine'] != 'Yahoo']

# Print the resulting DataFrame
print(ac2)
# Out:
#                                                 Query  ...     Variance
# 0                Vessel caught bypassing quota system  ...    18.580355
# 1                Vessel caught bypassing quota system  ...  1869.767002
# 3               Vessel caught falsifying fishing logs  ...     7.633171
# 4               Vessel caught falsifying fishing logs  ...   318.686758
# 6             Vessel caught misreporting catch amount  ...     1.840586
# 7             Vessel caught misreporting catch amount  ...   641.870335
# 9            Vessel caught misreporting haddock catch  ...   115.687651
# 10           Vessel caught misreporting haddock catch  ...   359.500000
# 12   Vessel caught misreporting tuna catch quantities  ...    47.306912
# 13   Vessel caught misreporting tuna catch quantities  ...  1336.596278
# 15  Vessel caught underreporting catch in North At...  ...     6.273386
# 16  Vessel caught underreporting catch in North At...  ...  1379.620119
# 18  Vessel caught underreporting catch near protec...  ...     8.209005
# 19  Vessel caught underreporting catch near protec...  ...  1217.536862
# 21    Vessel caught with inaccurate fish size records  ...    49.937359
# 22    Vessel caught with inaccurate fish size records  ...  1266.872380
# 24         Vessel caught with incorrect catch reports  ...     4.348531
# 25         Vessel caught with incorrect catch reports  ...   526.767748
# 27         Vessel caught with unrecorded fish species  ...    21.514708
# 28         Vessel caught with unrecorded fish species  ...   594.907428
#
# [20 rows x 4 columns]

# %%
ac2['Engine'].iloc[2]
# Out:
# 'Bing'

# %%
type(variances)
# Out:
# list

# %%
ac1["Variance"]
# Out:
# 0       18.580355
# 1     1869.767002
# 2        0.000000
# 3        7.633171
# 4      318.686758
# 5        0.000000
# 6        1.840586
# 7      641.870335
# 8        0.000000
# 9      115.687651
# 10     359.500000
# 11       0.000000
# 12      47.306912
# 13    1336.596278
# 14       0.000000
# 15       6.273386
# 16    1379.620119
# 17       0.000000
# 18       8.209005
# 19    1217.536862
# 20       0.000000
# 21      49.937359
# 22    1266.872380
# 23       0.000000
# 24       4.348531
# 25     526.767748
# 26     226.858069
# 27      21.514708
# 28     594.907428
# 29       0.000000
# Name: Variance, dtype: float64

# %% [markdown]
# ### Google Variance

# %%
# "MnG = ", mng , 
meang=[]
for i in range(len(ac1)):
    if ac1["Engine"].iloc[i] == 'Google':
        meang.append(ac1["Variance"].iloc[i])
    #for j in range(len(meang)):
        #mng = meang[j].sum()
        #mng = mng/len(meang)
#print("MeanG = ", meang)

fig = plt.figure(figsize =(10, 7))
# figure related code
fig = plt.figure()
fig.suptitle('Google Variance', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(meang)

#ax.set_title('axes title')
ax.set_xlabel('Google Engin')
ax.set_ylabel('Variance')

plt.show();

# %%
type(meang)
# Out:
# list

# %% [markdown]
# ### Yahoo Variance

# %%
# "MnY = ", mny,
meany=[]
for i in range(len(ac1)):
    if ac1["Engine"].iloc[i] == 'Yahoo':
        meany.append(ac1["Variance"].iloc[i])
    #for j in range(len(meany)):
        #mny = meany[j].sum()
        #mny = mny/len(meany)
#print(  "MeanY = ", meany )


fig = plt.figure(figsize =(10, 7))
# figure related code
fig = plt.figure()
fig.suptitle('Yahoo Variance', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(meany)

#ax.set_title('axes title')
ax.set_xlabel('Yahoo Engin')
ax.set_ylabel('Variance')

plt.show();

# %% [markdown]
# ### Bing Variance

# %%
# "MnB = ", mnb, 
meanb=[]
for i in range(len(ac1)):
    if ac1["Engine"].iloc[i] == 'Bing':
        meanb.append(ac1["Variance"].iloc[i])
    #for j in range(len(meanb)):
        #mnb = meanb[j].sum()
        #mnb = mnb/len(meanb)
#print( "MeanB = ", meanb)



fig = plt.figure(figsize =(10, 7))
# figure related code
fig = plt.figure()
fig.suptitle('Bing Variance', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(meanb)

#ax.set_title('axes title')
ax.set_xlabel('Bing Engin')
ax.set_ylabel('Variance')

plt.show();

# %%
### All

# %%
# Combine the lists into a single list for plotting
data = [meang, meanb]

# Labels for the boxplots
labels = ['Google', 'Bing']

# Plotting
plt.figure(figsize=(7, 6))
plt.boxplot(data, labels=labels)
plt.title('Days for Different Engines', fontsize=14)
plt.xlabel('Engine', fontsize=14)
plt.ylabel('Days', fontsize=14)
# Show the plot
plt.show()

# %% [markdown]
# ### Variances of per Query and Engine

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Grouping and resetting index
#article_counts = e.groupby(['Query', 'Engine', 'results']).size().reset_index(name='Article Count')

# Dropping the 'Article Count' column
# ac = article_counts.drop(['Article Count'], axis=1)

# Extracting every third query from the 'Query' column
queries_list = [ ac1['Query'].iloc[i] for i in range(0, len(ac1['Query']), 3)]

queries_labels = [f'Q_{i}' for i in range(1, 11)]


# Filtering the DataFrame to only include the queries in queries_list
filtered_ac = ac1[ac1['Query'].isin(queries_list)]

#color = ['lightblue', 'lightpurple', 'lightgreen']
# Plotting
plt.figure(figsize=(9, 7))
sns.barplot(x='Query', y='Variance', hue='Engine', data=filtered_ac )
plt.title('Days per Query and Engine', fontsize=14)

# Set xticks with query names
plt.xticks(ticks=range(len(queries_labels)), labels=queries_labels, rotation=0, ha='right')
plt.xlabel('Query', fontsize=14)
plt.ylabel('Days ', fontsize=14)
plt.legend(title='Engine', loc='upper right')
plt.tight_layout()
plt.grid(axis = 'y', linestyle='--')
# Show the plot
plt.show()

# %% [markdown]
# ### Variances of per Query and Engine by boxplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Grouping and resetting index
#article_counts = e.groupby(['Query', 'Engine', 'results']).size().reset_index(name='Article Count')

# Dropping the 'Article Count' column
# ac = article_counts.drop(['Article Count'], axis=1)

# Extracting every third query from the 'Query' column
queries_list = [ ac2['Query'].iloc[i] for i in range(0, len(ac2['Query']), 2)]

queries_labels = [f'Q_{i}' for i in range(1, 11)]


# Filtering the DataFrame to only include the queries in queries_list
filtered_ac = ac2[ac2['Query'].isin(queries_list)]

#color = ['lightblue', 'lightpurple', 'lightgreen']
# Plotting
plt.figure(figsize=(9, 7))
sns.barplot(x='Query', y='Variance', hue='Engine', data=filtered_ac )
plt.title('Days per Query and Engine', fontsize=14)

# Set xticks with query names
plt.xticks(ticks=range(len(queries_labels)), labels=queries_labels, rotation=0, ha='right')
plt.xlabel('Query', fontsize=14)
plt.ylabel('Days ', fontsize=14)
plt.legend(title='Engine', loc='upper right')
plt.tight_layout()
plt.grid(axis = 'y', linestyle='--')
# Show the plot
plt.show()

# %%
# Plotting a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Query', y='Variance', data=ac1)
plt.title('Distribution of days per Query',  fontsize=14)
plt.xticks(ticks=range(len(queries_labels)), labels=queries_labels, rotation=45, ha='right') # Set xticks with query names
plt.xlabel('Query', fontsize=14)
plt.ylabel('Days',  fontsize=14)
plt.xticks(rotation=0, ha='right')
plt.tight_layout()
plt.show()
